# %% [markdown]
# # EDA & Stationarity

# %%
import pandas as pd, matplotlib.pyplot as plt
from src.config import Config
cfg = Config(); ticker = cfg.default_ticker
df = pd.read_csv(cfg.processed_dir / f"{ticker}_processed.csv", parse_dates=["date"]).sort_values("date")
df.head()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['date'], df['close']); plt.title('Close'); plt.show()
